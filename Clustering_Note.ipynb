# %% [markdown]
# <a href="https://colab.research.google.com/github/Anusarakh/DPDM2021/blob/main/Clustering_Note.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clustering

# %% [markdown]
# ![cluster.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## K-means
#
# คือ วิธีการหนึ่งใน Data mining  อยู่ในกลุ่มของ Unsupervised Learning หรือแปลตรงๆคือการเรียนรู้แบบไม่ต้องสอน (Supervised Learning ต้องสอนก่อนต้องจับ Train และต้อง Test เป็นต้น) โดยหน้าที่หลักของ K-means คือการแบ่งกลุ่ม แบบ Clustering ซึ่งการแบ่งกลุ่มในลักษณะนี้จะใช้พื้นฐานทางสถิติ

# %% [markdown]
# ![257717345_438466224650385_4318967104625337641_n.jpg](data:image/jpeg;base64,...)![258326112_480259883292712_3613265194930948596_n.jpg](data:image/jpeg;base64,...)![257599981_666408944426205_8956992870257258049_n.jpg](data:image/jpeg;base64,...)![257665149_909510099935680_6868493247413619076_n.jpg](data:image/jpeg;base64,...)![258423633_215926407341244_8137268424023152454_n.jpg](data:image/jpeg;base64,...)
